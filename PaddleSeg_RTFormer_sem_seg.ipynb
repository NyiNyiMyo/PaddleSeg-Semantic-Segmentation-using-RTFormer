# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# %cd /mydrive/PaddleDet-Models
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# /content/gdrive/.shortcut-targets-by-id/17LXx-YpP2lamkZUgiY1A62xV8O46AQcz/PaddleDet-Models

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
import os
import json

def count_images(image_dir, exts={".jpg", ".jpeg", ".png", ".bmp", ".webp"}):
    image_count = 0
    for filename in os.listdir(image_dir):
        if os.path.splitext(filename.lower())[1] in exts:
            image_count += 1
    print(f"Total images: {image_count}")

count_images("datasets/sispanseg/train/images")
count_images("datasets/sispanseg/valid/images")
# Out:
# Total images: 200
# Total images: 56

# %%
import os
import random
import cv2
import numpy as np
import matplotlib.pyplot as plt

# -------------------------
# PATHS
# -------------------------
RGB_DIR = "datasets/sispanseg/train/rgbmasks"
MASK_DIR = "datasets/sispanseg/train/masks"

# -------------------------
# DEBUG COLORS (RGB)
# -------------------------
COLOR_Uterus = (255, 0, 255)            # Magenta - Suction
COLOR_BG = (150, 75, 0)                 # Brown
COLOR_Grasper_1 = (255, 0, 0)           # Red - Grasper
COLOR_Grasper_2 = (139, 0, 139)         # Purple
COLOR_Harmonic_ACE = (0, 255, 0)        # Green - Harmonic_Ace
COLOR_Myoma_Screw = (0, 0, 255)         # Blue - Myoma_Screw
COLOR_Needle_Holder_1 = (255, 255, 0)   # Yellow - Needle_Holder
COLOR_Needle_Holder_2 = (255, 174, 66)  # Orange Yellow
COLOR_Trocer = (0, 255, 255)            # Cyan - Trocar

Uterus = np.array(COLOR_Uterus)
BG = np.array(COLOR_BG)
Grasper_1 = np.array(COLOR_Grasper_1)
Grasper_2 = np.array(COLOR_Grasper_2)
Harmonic_ACE = np.array(COLOR_Harmonic_ACE)
Myoma_Screw = np.array(COLOR_Myoma_Screw)
Needle_Holder_1 = np.array(COLOR_Needle_Holder_1)
Needle_Holder_2 = np.array(COLOR_Needle_Holder_2)
Trocer = np.array(COLOR_Trocer)

# -------------------------
# LOAD FILES
# -------------------------
files = [f for f in os.listdir(RGB_DIR) if f.endswith(".png")]
samples = random.sample(files, 2)

# -------------------------
# FUNCTION: decode panoptic → RGB
# -------------------------
def decode_panoptic(mask):
    h, w = mask.shape
    out = np.zeros((h, w, 3), dtype=np.uint8)

    class_id = mask // 1000
    instance_id = mask % 1000

    # Grasper (class 1)
    Grasper1 = (class_id == 1) & (instance_id == 1)
    Grasper2 = (class_id == 1) & (instance_id == 2)

    out[Grasper1] = Grasper_1
    out[Grasper2] = Grasper_2

    # Harmonic (class 2)
    Harmonic = (class_id == 2)
    out[Harmonic] = Harmonic_ACE

    # Myoma Screw (class 3)
    Myoma = (class_id == 3)
    out[Myoma] = Myoma_Screw

    # Needle Holder (class 4)
    NeedleHolder1 = (class_id == 4) & (instance_id == 1)
    NeedleHolder2 = (class_id == 4) & (instance_id == 2)

    out[NeedleHolder1] = Needle_Holder_1
    out[NeedleHolder2] = Needle_Holder_2

    # Trocer (class 5)
    trocer = (class_id == 5)
    out[trocer] = Trocer

    # Uterus (class 6)
    uterus = (class_id == 6)
    out[uterus] = Uterus

    # Bg (class 7)
    Bg = (class_id == 7)
    out[Bg] = BG

    return out

# -------------------------
# PLOT
# -------------------------
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

for i, fname in enumerate(samples):
    rgb_path = os.path.join(RGB_DIR, fname)
    mask_path = os.path.join(MASK_DIR, fname)

    rgb = cv2.cvtColor(cv2.imread(rgb_path), cv2.COLOR_BGR2RGB)
    panoptic = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)

    decoded = decode_panoptic(panoptic)

    axes[i*2].imshow(rgb)
    axes[i*2].set_title(f"RGB Mask")
    axes[i*2].axis("off")

    axes[i*2+1].imshow(decoded)
    axes[i*2+1].set_title(f"Decoded Panoptic")
    axes[i*2+1].axis("off")

plt.tight_layout()
plt.show()

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

def convert_to_semantic(src_dir, dest_dir):
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    files = [f for f in os.listdir(src_dir) if f.endswith(".png")]
    print(f"Converting {len(files)} masks from {src_dir}...")

    for fname in tqdm(files):
        mask_path = os.path.join(src_dir, fname)
        # Load the panoptic mask (class * 1000 + instance)
        panoptic = cv2.imread(mask_path, cv2.IMREAD_UNCHANGED)

        # Get the class IDs
        class_id = panoptic // 1000

        # Initialize output grayscale mask (background/void = 255)
        semantic = np.full(panoptic.shape, 255, dtype=np.uint8)

        # 1. Map all THING classes to 0
        semantic[(class_id >= 1) & (class_id <= 5)] = 0

        # 2. Map STUFF classes to contiguous IDs starting from 1
        # Uterus (6) -> 1, BG (7) -> 2
        semantic[class_id == 6] = 1
        semantic[class_id == 7] = 2

        # Save as 8-bit grayscale PNG
        cv2.imwrite(os.path.join(dest_dir, fname), semantic)

# Convert Train and Val
convert_to_semantic("datasets/sispanseg/train/masks", "datasets/sispanseg/train/sem_seg")
convert_to_semantic("datasets/sispanseg/valid/masks", "datasets/sispanseg/valid/sem_seg")

# %%
import os
import json

def count_images(image_dir, exts={".jpg", ".jpeg", ".png", ".bmp", ".webp"}):
    image_count = 0
    for filename in os.listdir(image_dir):
        if os.path.splitext(filename.lower())[1] in exts:
            image_count += 1
    print(f"Total images: {image_count}")

count_images("datasets/sispanseg/train/sem_seg")
count_images("datasets/sispanseg/valid/sem_seg")
# Out:
# Total images: 200
# Total images: 56

# %%
from pathlib import Path

root_path = Path(r'/content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train')

images_path = root_path/'images'
masks_path = root_path/'sem_seg'

train_txt = open(root_path/'train.txt', 'w')

for mask_path in masks_path.rglob('*.png'):
    train_txt.write(f'{images_path}/{mask_path.stem}.jpg {masks_path}/{mask_path.name} \n')
train_txt.close()

# %%
from pathlib import Path

root_path = Path(r'/content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid')

images_path = root_path/'images'
masks_path = root_path/'sem_seg'

val_txt = open(root_path/'val.txt', 'w')

for mask_path in masks_path.rglob('*.png'):
    val_txt.write(f'{images_path}/{mask_path.stem}.jpg {masks_path}/{mask_path.name} \n')
val_txt.close()

# %%
# !git clone https://github.com/PaddlePaddle/PaddleSeg.git
# %cd PaddleSeg
# Out:
# fatal: destination path 'PaddleSeg' already exists and is not an empty directory.
# /content/gdrive/.shortcut-targets-by-id/17LXx-YpP2lamkZUgiY1A62xV8O46AQcz/PaddleDet-Models/PaddleSeg

# %%
# !pip install paddlepaddle-gpu pyclipper attrdict gdown -qqq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 58.7 MB/s eta 0:00:00

# %%
# !pip install -v -e .

# %%
# Force the "bridge" version of NumPy that works for both Python 3.12 and Paddle
# !pip install numpy==1.26.4 --force-reinstall

# Re-install OpenCV without dependencies to stop it from fighting with NumPy
# !pip install opencv-python-headless --no-deps --force-reinstall

# %%
# !python -c "import paddle; print(paddle.__version__); print(paddle.device.get_device()); import paddleseg; print(paddleseg.__version__)"
# Out:
# 2.6.2
# gpu:0
# 0.0.0.dev0

# %%
# !python tools/predict.py --help

# %%
# !python tools/predict.py \
       --config configs/rtformer/rtformer_base_ade20k_512x512_160k.yml \
       --model_path https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams \
       --device gpu \
       --image_path /content/gdrive/MyDrive/PaddleDet-Models/datasets/panoptic-tests-ade/ \
       --save_dir output/rtformer_results
# Out:
# [2026/05/05 09:02:54] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/05 09:02:54] INFO:
# ---------------Config Information---------------
# batch_size: 4
# iters: 160000
# train_dataset:
#   dataset_root: data/ADEChallengeData2016/
#   mode: train
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 512
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - mean:
#     - 0.485
#     - 0.456
#     - 0.406
#     std:
#     - 0.229
#     - 0.224
#     - 0.225
#     type: Normalize
#   type: ADE20K
# val_dataset:
#   dataset_root: data/ADEChallengeData2016/
#   mode: val
#   transforms:
#   - keep_ratio: true
#     size_divisor: 32
#     target_size:
#     - 2048
#     - 512
#     type: Resize
#   - mean:
#     - 0.485
#     - 0.456
#     - 0.406
#     std:
#     - 0.229
#     - 0.224
#     - 0.225
#     type: Normalize
#   type: ADE20K
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# lr_scheduler:
#   end_lr: 1.0e-07
#   learning_rate: 0.0001
#   power: 1.0
#   type: PolynomialDecay
#   warmup_iters: 1500
#   warmup_start_lr: 1.0e-06
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/backbone/rtformer_base_backbone_imagenet_pretrained.zip
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# ------------------------------------------------
#
# [2026/05/05 09:02:54] INFO: Set device: gpu:0
# [2026/05/05 09:02:54] WARNING: Add the `num_classes` in train_dataset class to model config. We suggest you manually set `num_classes` in model config.
# [2026/05/05 09:02:54] WARNING: Add the `in_channels` in train_dataset class to model config. We suggest you manually set `in_channels` in model config.
# [2026/05/05 09:02:54] INFO: Use the following config to build model
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   in_channels: 3
#   num_classes: 150
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/backbone/rtformer_base_backbone_imagenet_pretrained.zip
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# W0505 09:02:54.471238  4278 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0505 09:02:54.471285  4278 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/05 09:02:54] INFO: Loading pretrained model from https://paddleseg.bj.bcebos.com/dygraph/backbone/rtformer_base_backbone_imagenet_pretrained.zip
# Connecting to https://paddleseg.bj.bcebos.com/dygraph/backbone/rtformer_base_backbone_imagenet_pretrained.zip
# Downloading rtformer_base_backbone_imagenet_pretrained.zip
# [==================================================] 100.00%
# Uncompress rtformer_base_backbone_imagenet_pretrained.zip
# [==================================================] 100.00%
# [2026/05/05 09:03:12] WARNING: spp.scale1.1.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale1.1.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale1.1._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale1.1._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale1.3.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale2.1.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale2.1.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale2.1._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale2.1._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale2.3.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale3.1.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale3.1.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale3.1._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale3.1._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale3.3.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale4.1.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale4.1.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale4.1._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale4.1._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale4.3.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale0.0.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale0.0.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale0.0._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale0.0._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.scale0.2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process1.0.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process1.0.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process1.0._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process1.0._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process1.2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process2.0.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process2.0.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process2.0._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process2.0._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process2.2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process3.0.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process3.0.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process3.0._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process3.0._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process3.2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process4.0.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process4.0.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process4.0._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process4.0._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.process4.2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.compression.0.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.compression.0.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.compression.0._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.compression.0._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.compression.2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.shortcut.0.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.shortcut.0.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.shortcut.0._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.shortcut.0._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: spp.shortcut.2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.bn1.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.bn1.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.bn1._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.bn1._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.conv1.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.bn2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.bn2.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.bn2._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.bn2._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.conv2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead.conv2.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.bn1.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.bn1.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.bn1._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.bn1._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.conv1.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.bn2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.bn2.bias is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.bn2._mean is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.bn2._variance is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.conv2.weight is not in pretrained model
# [2026/05/05 09:03:12] WARNING: seghead_extra.conv2.bias is not in pretrained model
# [2026/05/05 09:03:12] INFO: There are 184/261 variables loaded into RTFormer.
# [2026/05/05 09:03:12] INFO: The number of images: 16
# [2026/05/05 09:03:12] INFO: Loading pretrained model from https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
# Connecting to https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
# Downloading model.pdparams
# [==================================================] 100.00%
# [2026/05/05 09:03:57] INFO: There are 261/261 variables loaded into RTFormer.
# [2026/05/05 09:03:57] INFO: Start to predict...
# 16/16 [==============================] - 20s 1s/step
# [2026/05/05 09:04:17] INFO: Predicted images are saved in output/rtformer_results/added_prediction and output/rtformer_results/pseudo_color_prediction .

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('output/rtformer_results/pseudo_color_prediction/street1.png')

plt.figure("Image")
plt.imshow(img)
plt.show()

# %%
# !ls configs/rtformer/
# Out:
# README.md
# rtformer_base_ade20k_512x512_160k.yml
# rtformer_base_cityscapes_1024x512_120k.yml
# rtformer_slim_ade20k_512x512_160k.yml
# rtformer_slim_cityscapes_1024x512_120k.yml
# rtformer_uterus.yml

# %%
one_epoch = 200/8
print(one_epoch)
total_iters = one_epoch * 20
print(total_iters)
# Out:
# 25.0
# 500.0

# %%
custom_cfg = """
batch_size: 8
iters: 500

train_dataset:
  type: Dataset
  dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
  train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
  num_classes: 3
  transforms:
    - type: ResizeStepScaling
      min_scale_factor: 0.5
      max_scale_factor: 2.0
      scale_step_size: 0.25
    - type: RandomPaddingCrop
      crop_size: [1024, 512]
    - type: RandomHorizontalFlip
    - type: RandomDistort
      brightness_range: 0.4
      contrast_range: 0.4
      saturation_range: 0.4
    - type: Normalize
  mode: train

val_dataset:
  type: Dataset
  dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
  val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
  num_classes: 3
  transforms:
    - type: Normalize
  mode: val

model:
  type: RTFormer
  base_channels: 64
  head_channels: 128
  drop_path_rate: 0.1
  use_injection: [True, False]
  pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams

optimizer:
  type: AdamW
  beta1: 0.9
  beta2: 0.999
  weight_decay: 0.05

lr_scheduler:
  type: PolynomialDecay
  learning_rate: 1.0e-4
  power: 1.
  end_lr: 1.0e-7
  warmup_iters: 100
  warmup_start_lr: 1.0e-6

loss:
  types:
    - type: CrossEntropyLoss
  coef: [1, 0.4]
"""

with open('configs/rtformer/rtformer_uterus.yml', 'w') as f:
    f.write(custom_cfg)

# %%
# !python tools/train.py --help

# usage: train.py [-h] [--config CONFIG] [--device {cpu,gpu,xpu,npu,mlu}]
#                 [--save_dir SAVE_DIR] [--num_workers NUM_WORKERS] [--do_eval]
#                 [--use_vdl] [--use_ema] [--resume_model RESUME_MODEL]
#                 [--iters ITERS] [--batch_size BATCH_SIZE]
#                 [--learning_rate LEARNING_RATE]
#                 [--save_interval SAVE_INTERVAL] [--log_iters LOG_ITERS]
#                 [--keep_checkpoint_max KEEP_CHECKPOINT_MAX]
#                 [--early_stop_intervals EARLY_STOP_INTERVALS] [--seed SEED]
#                 [--precision {fp32,fp16}] [--amp_level {O1,O2}]
#                 [--profiler_options PROFILER_OPTIONS]
#                 [--data_format DATA_FORMAT] [--repeats REPEATS]
#                 [--opts OPTS [OPTS ...]] [--use_multilabel]
#                 [--to_static_training] [--output_op {argmax,softmax,none}]
#                 [--input_shape INPUT_SHAPE [INPUT_SHAPE ...]] [--for_fd]

# %%
# !python tools/train.py \
       --config configs/rtformer/rtformer_uterus.yml \
       --device gpu \
       --num_workers 8 \
       --do_eval \
       --use_vdl \
       --save_interval 50 \
       --log_iters 5 \
       --keep_checkpoint_max 2 \
       --save_dir /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus
# Out:
# [2026/05/05 10:41:11] WARNING: Add the `num_classes` in train_dataset and val_dataset config to model config. We suggest you manually set `num_classes` in model config.
# [2026/05/05 10:41:11] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/05 10:41:11] INFO:
# ---------------Config Information---------------
# batch_size: 8
# iters: 500
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# lr_scheduler:
#   end_lr: 1.0e-07
#   learning_rate: 0.0001
#   power: 1.0
#   type: PolynomialDecay
#   warmup_iters: 100
#   warmup_start_lr: 1.0e-06
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# ------------------------------------------------
#
# [2026/05/05 10:41:11] INFO: Set device: gpu
# [2026/05/05 10:41:11] INFO: Use the following config to build model
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# W0505 10:41:11.315198 34613 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0505 10:41:11.315236 34613 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/05 10:41:11] INFO: Loading pretrained model from https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
# [2026/05/05 10:41:11] WARNING: [SKIP] Shape of pretrained params seghead.conv2.weight doesn't match.(Pretrained: [150, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/05 10:41:11] WARNING: [SKIP] Shape of pretrained params seghead.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 10:41:11] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.weight doesn't match.(Pretrained: [150, 128, 1, 1], Actual: [3, 128, 1, 1])
# [2026/05/05 10:41:11] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 10:41:11] INFO: There are 257/261 variables loaded into RTFormer.
# [2026/05/05 10:41:11] INFO: Use the following config to build train_dataset
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# [2026/05/05 10:41:11] INFO: Use the following config to build val_dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# [2026/05/05 10:41:11] INFO: Use the following config to build optimizer
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# [2026/05/05 10:41:11] INFO: Use the following config to build loss
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# /usr/local/lib/python3.12/dist-packages/paddle/nn/layer/norm.py:824: UserWarning: When training, we now always track global mean and variance.
#   warnings.warn(
# [2026/05/05 10:41:28] INFO: [TRAIN] epoch: 1, iter: 5/500, loss: 1.6265, lr: 0.000005, batch_cost: 3.3655, reader_cost: 1.44012, ips: 2.3771 samples/sec, max_mem_reserved: 4554 MB, max_mem_allocated: 4066 MB | ETA 00:27:45
# [2026/05/05 10:41:33] INFO: [TRAIN] epoch: 1, iter: 10/500, loss: 1.5508, lr: 0.000010, batch_cost: 0.8773, reader_cost: 0.00104, ips: 9.1184 samples/sec, max_mem_reserved: 5141 MB, max_mem_allocated: 4066 MB | ETA 00:07:09
# [2026/05/05 10:41:36] INFO: [TRAIN] epoch: 1, iter: 15/500, loss: 1.4225, lr: 0.000015, batch_cost: 0.6964, reader_cost: 0.00067, ips: 11.4882 samples/sec, max_mem_reserved: 5141 MB, max_mem_allocated: 4066 MB | ETA 00
samples/sec, max_mem_reserved: 5141 MB, max_mem_allocated: 4066 MB | ETA 00:00:08
# [2026/05/05 10:52:26] INFO: [TRAIN] epoch: 20, iter: 495/500, loss: 0.2408, lr: 0.000002, batch_cost: 0.5889, reader_cost: 0.00165, ips: 13.5847 samples/sec, max_mem_reserved: 5141 MB, max_mem_allocated: 4066 MB | ETA 00:00:02
# [2026/05/05 10:52:29] INFO: [TRAIN] epoch: 20, iter: 500/500, loss: 0.3616, lr: 0.000000, batch_cost: 0.5336, reader_cost: 0.00021, ips: 14.9925 samples/sec, max_mem_reserved: 5141 MB, max_mem_allocated: 4066 MB | ETA 00:00:00
# [2026/05/05 10:52:29] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 9s 162ms/step - batch_cost: 0.1612 - reader cost: 0.1128
# [2026/05/05 10:52:38] INFO: [EVAL] #Images: 56 mIoU: 0.8600 Acc: 0.9449 Kappa: 0.8912 Dice: 0.9239
# [2026/05/05 10:52:38] INFO: [EVAL] Class IoU:
# [0.7991 0.8531 0.9278]
# [2026/05/05 10:52:38] INFO: [EVAL] Class Precision:
# [0.9251 0.8953 0.971 ]
# [2026/05/05 10:52:38] INFO: [EVAL] Class Recall:
# [0.8544 0.9477 0.9543]
# [2026/05/05 10:52:39] INFO: [EVAL] The model with the best validation mIoU (0.8619) was saved at iter 400.
# <class 'paddle.nn.layer.conv.Conv2D'>'s flops has been counted
# <class 'paddle.nn.layer.norm.BatchNorm2D'>'s flops has been counted
# <class 'paddle.nn.layer.activation.ReLU'>'s flops has been counted
# Cannot find suitable count function for <class 'paddle.nn.layer.activation.GELU'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.common.Dropout'>'s flops has been counted
# Cannot find suitable count function for <class 'paddleseg.models.backbones.transformer_utils.DropPath'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddle.nn.layer.pooling.AdaptiveMaxPool2D'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.pooling.AvgPool2D'>'s flops has been counted
# <class 'paddle.nn.layer.pooling.AdaptiveAvgPool2D'>'s flops has been counted
# Total Flops: 33746015744     Total Params: 16869443

# %%
# !python tools/train.py \
       --config configs/rtformer/rtformer_uterus.yml \
       --device gpu \
       --num_workers 8 \
       --do_eval \
       --use_vdl \
       --resume_model /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/iter_500 \
       --iters 1000 \
       --save_interval 50 \
       --log_iters 5 \
       --keep_checkpoint_max 2 \
       --save_dir /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus
# Out:
# [2026/05/05 10:56:37] WARNING: Add the `num_classes` in train_dataset and val_dataset config to model config. We suggest you manually set `num_classes` in model config.
# [2026/05/05 10:56:37] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/05 10:56:37] INFO:
# ---------------Config Information---------------
# batch_size: 8
# iters: 1000
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# lr_scheduler:
#   end_lr: 1.0e-07
#   learning_rate: 0.0001
#   power: 1.0
#   type: PolynomialDecay
#   warmup_iters: 100
#   warmup_start_lr: 1.0e-06
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# ------------------------------------------------
#
# [2026/05/05 10:56:37] INFO: Set device: gpu
# [2026/05/05 10:56:37] INFO: Use the following config to build model
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# W0505 10:56:37.958942 39787 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0505 10:56:37.958993 39787 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/05 10:56:38] INFO: Loading pretrained model from https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
# [2026/05/05 10:56:38] WARNING: [SKIP] Shape of pretrained params seghead.conv2.weight doesn't match.(Pretrained: [150, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/05 10:56:38] WARNING: [SKIP] Shape of pretrained params seghead.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 10:56:38] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.weight doesn't match.(Pretrained: [150, 128, 1, 1], Actual: [3, 128, 1, 1])
# [2026/05/05 10:56:38] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 10:56:38] INFO: There are 257/261 variables loaded into RTFormer.
# [2026/05/05 10:56:38] INFO: Use the following config to build train_dataset
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# [2026/05/05 10:56:38] INFO: Use the following config to build val_dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# [2026/05/05 10:56:38] INFO: Use the following config to build optimizer
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# [2026/05/05 10:56:38] INFO: Use the following config to build loss
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# [2026/05/05 10:56:38] INFO: Resume model from /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/iter_500
# /usr/local/lib/python3.12/dist-packages/paddle/optimizer/lr.py:252: UserWarning: There are some unused values in state_dict. Maybe the optimizer have different 'LearningRateDecay' when invoking state_dict and set_dict
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/paddle/nn/layer/norm.py:824: UserWarning: When training, we now always track global mean and variance.
#   warnings.warn(
# [2026/05/05 10:56:55] INFO: [TRAIN] epoch: 21, iter: 505/1000, loss: 0.2437, lr: 0.000055, batch_cost: 3.3623, reader_cost: 1.63331, ips: 2.3793 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:27:44
# [2026/05/05 10:57:01] INFO: [TRAIN] epoch: 21, iter: 510/1000, loss: 0.3714, lr: 0.000055, batch_cost: 1.0512, reader_cost: 0.00485, ips: 7.6106 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:08:35
# [2026/05/05 10:57:04] INFO: [TRAIN] epoch: 21, iter: 515/1000, loss: 0.2358, lr: 0.000054, batch_cost: 0.6490, reader_cost: 0.00294, ips: 12.3276 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:05:14
# [2026/05/05 10:57:06] INFO: [TRAIN] epoch: 21, iter: 520/1000, loss: 0.3440, lr: 0.000053, batch_cost: 0.5091, reader_cost: 0.00022, ips: 15.7147 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:04
# [2026/05/05 10:57:09] INFO: [TRAIN] epoch: 21, iter: 525/1000, loss: 0.2893, lr: 0.000053, batch_cost: 0.4978, reader_cost: 0.00021, ips: 16.0719 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:56
# [2026/05/05 10:57:23] INFO: [TRAIN] epoch: 22, iter: 530/1000, loss: 0.4289, lr: 0.000052, batch_cost: 2.7790, reader_cost: 1.84227, ips: 2.8788 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:21:46
# [2026/05/05 10:57:28] INFO: [TRAIN] epoch: 22, iter: 535/1000, loss: 0.2868, lr: 0.000052, batch_cost: 0.9312, reader_cost: 0.00154, ips: 8.5914 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:07:12
# [2026/05/05 10:57:32] INFO: [TRAIN] epoch: 22, iter: 540/1000, loss: 0.2951, lr: 0.000051, batch_cost: 0.9248, reader_cost: 0.00125, ips: 8.6506 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:07:05
# [2026/05/05 10:57:35] INFO: [TRAIN] epoch: 22, iter: 545/1000, loss: 0.2636, lr: 0.000051, batch_cost: 0.5522, reader_cost: 0.00061, ips: 14.4886 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:11
# [2026/05/05 10:57:37] INFO: [TRAIN] epoch: 22, iter: 550/1000, loss: 0.4872, lr: 0.000050, batch_cost: 0.5112, reader_cost: 0.00020, ips: 15.6508 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:50
# [2026/05/05 10:57:37] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 6s 113ms/step - batch_cost: 0.1126 - reader cost: 0.0735
# [2026/05/05 10:57:44] INFO: [EVAL] #Images: 56 mIoU: 0.8556 Acc: 0.9435 Kappa: 0.8880 Dice: 0.9212
# [2026/05/05 10:57:44] INFO: [EVAL] Class IoU:
# [0.7928 0.8467 0.9273]
# [2026/05/05 10:57:44] INFO: [EVAL] Class Precision:
# [0.8977 0.9037 0.9671]
# [2026/05/05 10:57:44] INFO: [EVAL] Class Recall:
# [0.8715 0.9306 0.9575]
# [2026/05/05 10:57:46] INFO: [EVAL] The model with the best validation mIoU (0.8556) was saved at iter 550.
# [2026/05/05 10:57:59] INFO: [TRAIN] epoch: 23, iter: 555/1000, loss: 0.3351, lr: 0.000050, batch_cost: 2.6738, reader_cost: 1.67792, ips: 2.9920 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00
samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:19
# [2026/05/05 11:07:02] INFO: [TRAIN] epoch: 39, iter: 975/1000, loss: 0.2791, lr: 0.000003, batch_cost: 0.5281, reader_cost: 0.00024, ips: 15.1492 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:13
# [2026/05/05 11:07:16] INFO: [TRAIN] epoch: 40, iter: 980/1000, loss: 0.3157, lr: 0.000002, batch_cost: 2.8016, reader_cost: 1.89019, ips: 2.8555 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:56
# [2026/05/05 11:07:22] INFO: [TRAIN] epoch: 40, iter: 985/1000, loss: 0.3522, lr: 0.000002, batch_cost: 1.2160, reader_cost: 0.00287, ips: 6.5792 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:18
# [2026/05/05 11:07:26] INFO: [TRAIN] epoch: 40, iter: 990/1000, loss: 0.2524, lr: 0.000001, batch_cost: 0.7329, reader_cost: 0.00124, ips: 10.9149 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:07
# [2026/05/05 11:07:29] INFO: [TRAIN] epoch: 40, iter: 995/1000, loss: 0.2103, lr: 0.000001, batch_cost: 0.5449, reader_cost: 0.00040, ips: 14.6807 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:02
# [2026/05/05 11:07:31] INFO: [TRAIN] epoch: 40, iter: 1000/1000, loss: 0.2413, lr: 0.000000, batch_cost: 0.5361, reader_cost: 0.00021, ips: 14.9223 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:00
# [2026/05/05 11:07:31] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 8s 148ms/step - batch_cost: 0.1473 - reader cost: 0.0951
# [2026/05/05 11:07:40] INFO: [EVAL] #Images: 56 mIoU: 0.8823 Acc: 0.9529 Kappa: 0.9073 Dice: 0.9370
# [2026/05/05 11:07:40] INFO: [EVAL] Class IoU:
# [0.8368 0.8738 0.9364]
# [2026/05/05 11:07:40] INFO: [EVAL] Class Precision:
# [0.9218 0.909  0.9776]
# [2026/05/05 11:07:40] INFO: [EVAL] Class Recall:
# [0.9008 0.9576 0.9569]
# [2026/05/05 11:07:41] INFO: [EVAL] The model with the best validation mIoU (0.8823) was saved at iter 1000.
# <class 'paddle.nn.layer.conv.Conv2D'>'s flops has been counted
# <class 'paddle.nn.layer.norm.BatchNorm2D'>'s flops has been counted
# <class 'paddle.nn.layer.activation.ReLU'>'s flops has been counted
# Cannot find suitable count function for <class 'paddle.nn.layer.activation.GELU'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.common.Dropout'>'s flops has been counted
# Cannot find suitable count function for <class 'paddleseg.models.backbones.transformer_utils.DropPath'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddle.nn.layer.pooling.AdaptiveMaxPool2D'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.pooling.AvgPool2D'>'s flops has been counted
# <class 'paddle.nn.layer.pooling.AdaptiveAvgPool2D'>'s flops has been counted
# Total Flops: 33746015744     Total Params: 16869443

# %%
# !python tools/train.py \
       --config configs/rtformer/rtformer_uterus.yml \
       --device gpu \
       --num_workers 8 \
       --do_eval \
       --use_vdl \
       --resume_model /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/iter_1000 \
       --iters 1500 \
       --save_interval 50 \
       --log_iters 5 \
       --keep_checkpoint_max 2 \
       --save_dir /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus
# Out:
# [2026/05/05 11:19:17] WARNING: Add the `num_classes` in train_dataset and val_dataset config to model config. We suggest you manually set `num_classes` in model config.
# [2026/05/05 11:19:17] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/05 11:19:17] INFO:
# ---------------Config Information---------------
# batch_size: 8
# iters: 1500
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# lr_scheduler:
#   end_lr: 1.0e-07
#   learning_rate: 0.0001
#   power: 1.0
#   type: PolynomialDecay
#   warmup_iters: 100
#   warmup_start_lr: 1.0e-06
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# ------------------------------------------------
#
# [2026/05/05 11:19:17] INFO: Set device: gpu
# [2026/05/05 11:19:17] INFO: Use the following config to build model
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# W0505 11:19:17.717645 46934 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0505 11:19:17.717690 46934 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/05 11:19:18] INFO: Loading pretrained model from https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
# [2026/05/05 11:19:18] WARNING: [SKIP] Shape of pretrained params seghead.conv2.weight doesn't match.(Pretrained: [150, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/05 11:19:18] WARNING: [SKIP] Shape of pretrained params seghead.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 11:19:18] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.weight doesn't match.(Pretrained: [150, 128, 1, 1], Actual: [3, 128, 1, 1])
# [2026/05/05 11:19:18] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 11:19:18] INFO: There are 257/261 variables loaded into RTFormer.
# [2026/05/05 11:19:18] INFO: Use the following config to build train_dataset
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# [2026/05/05 11:19:18] INFO: Use the following config to build val_dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# [2026/05/05 11:19:18] INFO: Use the following config to build optimizer
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# [2026/05/05 11:19:18] INFO: Use the following config to build loss
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# [2026/05/05 11:19:18] INFO: Resume model from /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/iter_1000
# /usr/local/lib/python3.12/dist-packages/paddle/optimizer/lr.py:252: UserWarning: There are some unused values in state_dict. Maybe the optimizer have different 'LearningRateDecay' when invoking state_dict and set_dict
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/paddle/nn/layer/norm.py:824: UserWarning: When training, we now always track global mean and variance.
#   warnings.warn(
# [2026/05/05 11:19:36] INFO: [TRAIN] epoch: 41, iter: 1005/1500, loss: 0.2717, lr: 0.000035, batch_cost: 3.5614, reader_cost: 1.51996, ips: 2.2463 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:29:22
# [2026/05/05 11:19:41] INFO: [TRAIN] epoch: 41, iter: 1010/1500, loss: 0.3214, lr: 0.000035, batch_cost: 0.8860, reader_cost: 0.00352, ips: 9.0295 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:07:14
# [2026/05/05 11:19:44] INFO: [TRAIN] epoch: 41, iter: 1015/1500, loss: 0.2597, lr: 0.000035, batch_cost: 0.6295, reader_cost: 0.00139, ips: 12.7095 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:05:05
# [2026/05/05 11:19:47] INFO: [TRAIN] epoch: 41, iter: 1020/1500, loss: 0.2789, lr: 0.000034, batch_cost: 0.5242, reader_cost: 0.00067, ips: 15.2625 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:11
# [2026/05/05 11:19:49] INFO: [TRAIN] epoch: 41, iter: 1025/1500, loss: 0.2584, lr: 0.000034, batch_cost: 0.5240, reader_cost: 0.00023, ips: 15.2686 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:08
# [2026/05/05 11:20:02] INFO: [TRAIN] epoch: 42, iter: 1030/1500, loss: 0.2845, lr: 0.000034, batch_cost: 2.5457, reader_cost: 1.62084, ips: 3.1426 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:19:56
# [2026/05/05 11:20:08] INFO: [TRAIN] epoch: 42, iter: 1035/1500, loss: 0.2562, lr: 0.000033, batch_cost: 1.1007, reader_cost: 0.00445, ips: 7.2682 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:08:31
# [2026/05/05 11:20:12] INFO: [TRAIN] epoch: 42, iter: 1040/1500, loss: 0.2328, lr: 0.000033, batch_cost: 0.9425, reader_cost: 0.00102, ips: 8.4882 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:07:13
# [2026/05/05 11:20:15] INFO: [TRAIN] epoch: 42, iter: 1045/1500, loss: 0.2467, lr: 0.000033, batch_cost: 0.5479, reader_cost: 0.00079, ips: 14.6013 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:09
# [2026/05/05 11:20:18] INFO: [TRAIN] epoch: 42, iter: 1050/1500, loss: 0.2490, lr: 0.000032, batch_cost: 0.5360, reader_cost: 0.00058, ips: 14.9257 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:01
# [2026/05/05 11:20:18] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 8s 138ms/step - batch_cost: 0.1374 - reader cost: 0.0887
# [2026/05/05 11:20:25] INFO: [EVAL] #Images: 56 mIoU: 0.8663 Acc: 0.9500 Kappa: 0.9010 Dice: 0.9273
# [2026/05/05 11:20:25] INFO: [EVAL] Class IoU:
# [0.7945 0.8683 0.9359]
# [2026/05/05 11:20:25] INFO: [EVAL] Class Precision:
# [0.8413 0.9434 0.9669]
# [2026/05/05 11:20:25] INFO: [EVAL] Class Recall:
# [0.9346 0.916  0.9669]
# [2026/05/05 11:20:27] INFO: [EVAL] The model with the best validation mIoU (0.8663) was saved at iter 1050.
# [2026/05/05 11:20:40] INFO: [TRAIN] epoch: 43, iter: 1055/1500, loss: 0.2503, lr: 0.000032, batch_cost: 2.5463, reader_cost: 1.31878, ips: 3.1418 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:18:53
# [2026/05/05 11:20:46] INFO: [TRAIN] epoch: 43, iter: 1060/1500, loss: 0.4056, lr: 0.000032, batch_cost: 1.0859, reader_cost: 0.21974, ips: 7.3674 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:07:57
# [2026/05/05 11:20:49] INFO: [TRAIN] epoch: 43, iter: 1065/1500, loss: 0.2625, lr: 0.000031, batch_cost: 0.6515, reader_cost: 0.00124, ips: 12.2799 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:43
# [2026/05/05 11:20:55] INFO: [TRAIN] epoch: 43, iter: 1070/1500, loss: 0.2427, lr: 0.000031, batch_cost: 1.1931, reader_cost: 0.57414, ips: 6.7052 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:08:33
# [2026/05/05 11:20:57] INFO: [TRAIN] epoch: 43, iter: 1075/1500, loss: 0.2892, lr: 0.000030, batch_cost: 0.5441, reader_cost: 0.00168, ips: 14.7036 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:51
# [2026/05/05 11:21:08] INFO: [TRAIN] epoch: 44, iter: 1080/1500, loss: 0.2380, lr: 0.000030, batch_cost: 2.1146, reader_cost: 1.22060, ips: 3.7833 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:14:48
# [2026/05/05 11:21:14] INFO: [TRAIN] epoch: 44, iter: 1085/1500, loss: 0.3344, lr: 0.000030, batch_cost: 1.1767, reader_cost: 0.09331, ips: 6.7989 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:08:08
# [2026/05/05 11:21:18] INFO: [TRAIN] epoch: 44, iter: 1090/1500, loss: 0.2610, lr: 0.000029, batch_cost: 0.8215, reader_cost: 0.00102, ips: 9.7380 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:05:36
# [2026/05/05 11:21:21] INFO: [TRAIN] epoch: 44, iter: 1095/1500, loss: 0.2575, lr: 0.000029, batch_cost: 0.5838, reader_cost: 0.00054, ips: 13.7039 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:56
# [2026/05/05 11:21:24] INFO: [TRAIN] epoch: 44, iter: 1100/1500, loss: 0.2365, lr: 0.000029, batch_cost: 0.5327, reader_cost: 0.00023, ips: 15.0183 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:33
# [2026/05/05 11:21:24] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 8s 144ms/step - batch_cost: 0.1433 - reader cost: 0.0955
# [2026/05/05 11:21:32] INFO: [EVAL] #Images: 56 mIoU: 0.8893 Acc: 0.9579 Kappa: 0.9161 Dice: 0.9409
# [2026/05/05 11:21:32] INFO: [EVAL] Class IoU:
# [0.8376 0.8863 0.9441]
# [2026/05/05 11:21:32] INFO: [EVAL] Class Precision:
# [0.926  0.9418 0.9686]
# [2026/05/05 11:21:32] INFO: [EVAL] Class Recall:
# [0.8977 0.9377 0.974 ]
# [2026/05/05 11:21:34] INFO: [EVAL] The model with the best validation mIoU (0.8893) was saved at iter 1100.
# [2026/05/05 11:21:48] INFO: [TRAIN] epoch: 45, iter: 1105/1500, loss: 0.4071, lr: 0.000028, batch_cost: 2.9545, reader_cost: 1.88434, ips: 2.7077 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:19:27
# [2026/05/05 11:21:54] INFO: [TRAIN] epoch: 45, iter: 1110/1500, loss: 0.2889, lr: 0.000028, batch_cost: 1.2030, reader_cost: 0.42573, ips: 6.6498 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:07:49
# [2026/05/05 11:21:59] INFO: [TRAIN] epoch: 45, iter: 1115/1500, loss: 0.2770, lr: 0.000028, batch_cost: 0.9198, reader_cost: 0.00083, ips: 8.6973 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:05:54
# [2026/05/05 11:22:02] INFO: [TRAIN] epoch: 45, iter: 1120/1500, loss: 0.2983, lr: 0.000027, batch_cost: 0.6232, reader_cost: 0.02129, ips: 12.8376 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:56
# [2026/05/05 11:22:05] INFO: [TRAIN] epoch: 45, iter: 1125/1500, loss: 0.2214, lr: 0.000027, batch_cost: 0.5263, reader_cost: 0.00021, ips: 15.2014 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:17
# [2026/05/05 11:22:20] INFO: [TRAIN] epoch: 46, iter: 1130/1500, loss: 0.3226, lr: 0.000027, batch_cost: 2.9711, reader_cost: 1.70089, ips: 2.6926 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:18:19
# [2026/05/05 11:22:24] INFO: [TRAIN] epoch: 46, iter: 1135/1500, loss: 0.2619, lr: 0.000026, batch_cost: 0.8396, reader_cost: 0.00258, ips: 9.5283 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:05:06
# [2026/05/05 11:22:27] INFO: [TRAIN] epoch: 46, iter: 1140/1500, loss: 0.3510, lr: 0.000026, batch_cost: 0.7119, reader_cost: 0.00189, ips: 11.2370 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:16
# [2026/05/05 11:22:30] INFO: [TRAIN] epoch: 46, iter: 1145/1500, loss: 0.2814, lr: 0.000026, batch_cost: 0.5651, reader_cost: 0.00112, ips: 14.1575 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:20
# [2026/05/05 11:22:33] INFO: [TRAIN] epoch: 46, iter: 1150/1500, loss: 0.3382, lr: 0.000025, batch_cost: 0.5528, reader_cost: 0.00100, ips: 14.4706 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:13
# [2026/05/05 11:22:33] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 7s 121ms/step - batch_cost: 0.1205 - reader cost: 0.0811
# [2026/05/05 11:22:40] INFO: [EVAL] #Images: 56 mIoU: 0.8734 Acc: 0.9518 Kappa: 0.9041 Dice: 0.9316
# [2026/05/05 11:22:40] INFO: [EVAL] Class IoU:
# [0.8098 0.8751 0.9354]
# [2026/05/05 11:22:40] INFO: [EVAL] Class Precision:
# [0.8778 0.9453 0.9635]
# [2026/05/05 11:22:40] INFO: [EVAL] Class Recall:
# [0.9127 0.9217 0.9698]
# [2026/05/05 11:22:41] INFO: [EVAL] The model with the best validation mIoU (0.8893) was saved at iter 1100.
# [2026/05/05 11:22:57] INFO: [TRAIN] epoch: 47, iter: 1155/1500, loss: 0.2779, lr: 0.000025, batch_cost: 3.0444, reader_cost: 2.02259, ips: 2.6277 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:17:30
# [2026/05/05 11:23:02] INFO: [TRAIN] epoch: 47, iter: 1160/1500, loss: 0.2923, lr: 0.000024, batch_cost: 1.0408, reader_cost: 0.00250, ips: 7.6864 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:05:53
# [2026/05/05 11:23:07] INFO: [TRAIN] epoch: 47, iter: 1165/1500, loss: 0.2486, lr: 0.000024, batch_cost: 0.9872, reader_cost: 0.00188, ips: 8.1034 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:05:30
# [2026/05/05 11:23:10] INFO: [TRAIN] epoch: 47, iter: 1170/1500, loss: 0.2547, lr: 0.000024, batch_cost: 0.5817, reader_cost: 0.00056, ips: 13.7526 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:11
# [2026/05/05 11:23:12] INFO: [TRAIN] epoch: 47, iter: 1175/1500, loss: 0.3555, lr: 0.000023, batch_cost: 0.5276, reader_cost: 0.00064, ips: 15.1628 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:51
# [2026/05/05 11:23:26] INFO: [TRAIN] epoch: 48, iter: 1180/1500, loss: 0.2338, lr: 0.000023, batch_cost: 2.7836, reader_cost: 1.88943, ips: 2.8740 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:14:50
# [2026/05/05 11:23:30] INFO: [TRAIN] epoch: 48, iter: 1185/1500, loss: 0.3451, lr: 0.000023, batch_cost: 0.8538, reader_cost: 0.00059, ips: 9.3701 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:28
# [2026/05/05 11:23:35] INFO: [TRAIN] epoch: 48, iter: 1190/1500, loss: 0.2964, lr: 0.000022, batch_cost: 0.9627, reader_cost: 0.00338, ips: 8.3103 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:58
# [2026/05/05 11:23:38] INFO: [TRAIN] epoch: 48, iter: 1195/1500, loss: 0.2864, lr: 0.000022, batch_cost: 0.6129, reader_cost: 0.00133, ips: 13.0534 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:06
# [2026/05/05 11:23:41] INFO: [TRAIN] epoch: 48, iter: 1200/1500, loss: 0.2911, lr: 0.000022, batch_cost: 0.5345, reader_cost: 0.00021, ips: 14.9686 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:40
# [2026/05/05 11:23:41] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 7s 120ms/step - batch_cost: 0.1196 - reader cost: 0.0813
# [2026/05/05 11:23:48] INFO: [EVAL] #Images: 56 mIoU: 0.8858 Acc: 0.9560 Kappa: 0.9131 Dice: 0.9388
# [2026/05/05 11:23:48] INFO: [EVAL] Class IoU:
# [0.835  0.8795 0.9428]
# [2026/05/05 11:23:48] INFO: [EVAL] Class Precision:
# [0.9546 0.9088 0.979 ]
# [2026/05/05 11:23:48] INFO: [EVAL] Class Recall:
# [0.8696 0.9647 0.9623]
# [2026/05/05 11:23:49] INFO: [EVAL] The model with the best validation mIoU (0.8893) was saved at iter 1100.
# [2026/05/05 11:24:02] INFO: [TRAIN] epoch: 49, iter: 1205/1500, loss: 0.2901, lr: 0.000021, batch_cost: 2.4711, reader_cost: 1.55867, ips: 3.2374 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:12:08
# [2026/05/05 11:24:08] INFO: [TRAIN] epoch: 49, iter: 1210/1500, loss: 0.2248, lr: 0.000021, batch_cost: 1.3239, reader_cost: 0.17821, ips: 6.0430 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:06:23
# [2026/05/05 11:24:13] INFO: [TRAIN] epoch: 49, iter: 1215/1500, loss: 0.2609, lr: 0.000021, batch_cost: 0.8575, reader_cost: 0.00021, ips: 9.3297 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:04
# [2026/05/05 11:24:15] INFO: [TRAIN] epoch: 49, iter: 1220/1500, loss: 0.2500, lr: 0.000020, batch_cost: 0.5429, reader_cost: 0.00060, ips: 14.7360 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:32
# [2026/05/05 11:24:18] INFO: [TRAIN] epoch: 49, iter: 1225/1500, loss: 0.2271, lr: 0.000020, batch_cost: 0.5253, reader_cost: 0.00023, ips: 15.2303 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:24
# [2026/05/05 11:24:32] INFO: [TRAIN] epoch: 50, iter: 1230/1500, loss: 0.2688, lr: 0.000019, batch_cost: 2.8404, reader_cost: 1.87639, ips: 2.8165 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:12:46
# [2026/05/05 11:24:38] INFO: [TRAIN] epoch: 50, iter: 1235/1500, loss: 0.2236, lr: 0.000019, batch_cost: 1.1040, reader_cost: 0.00435, ips: 7.2464 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:52
# [2026/05/05 11:24:43] INFO: [TRAIN] epoch: 50, iter: 1240/1500, loss: 0.2743, lr: 0.000019, batch_cost: 0.9391, reader_cost: 0.00302, ips: 8.5189 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:04
# [2026/05/05 11:24:45] INFO: [TRAIN] epoch: 50, iter: 1245/1500, loss: 0.2914, lr: 0.000018, batch_cost: 0.5378, reader_cost: 0.00075, ips: 14.8765 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:17
# [2026/05/05 11:24:48] INFO: [TRAIN] epoch: 50, iter: 1250/1500, loss: 0.2814, lr: 0.000018, batch_cost: 0.5363, reader_cost: 0.00030, ips: 14.9163 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:14
# [2026/05/05 11:24:48] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 8s 146ms/step - batch_cost: 0.1449 - reader cost: 0.0971
# [2026/05/05 11:24:56] INFO: [EVAL] #Images: 56 mIoU: 0.8870 Acc: 0.9552 Kappa: 0.9109 Dice: 0.9397
# [2026/05/05 11:24:56] INFO: [EVAL] Class IoU:
# [0.8442 0.877  0.9399]
# [2026/05/05 11:24:56] INFO: [EVAL] Class Precision:
# [0.915  0.9342 0.9692]
# [2026/05/05 11:24:56] INFO: [EVAL] Class Recall:
# [0.9161 0.9347 0.9688]
# [2026/05/05 11:24:57] INFO: [EVAL] The model with the best validation mIoU (0.8893) was saved at iter 1100.
# [2026/05/05 11:25:13] INFO: [TRAIN] epoch: 51, iter: 1255/1500, loss: 0.2929, lr: 0.000018, batch_cost: 3.1433, reader_cost: 1.85979, ips: 2.5451 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:12:50
# [2026/05/05 11:25:18] INFO: [TRAIN] epoch: 51, iter: 1260/1500, loss: 0.3274, lr: 0.000017, batch_cost: 0.9263, reader_cost: 0.00204, ips: 8.6363 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:42
# [2026/05/05 11:25:21] INFO: [TRAIN] epoch: 51, iter: 1265/1500, loss: 0.1898, lr: 0.000017, batch_cost: 0.7289, reader_cost: 0.00111, ips: 10.9759 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:51
# [2026/05/05 11:25:24] INFO: [TRAIN] epoch: 51, iter: 1270/1500, loss: 0.2320, lr: 0.000017, batch_cost: 0.5504, reader_cost: 0.00139, ips: 14.5359 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:06
# [2026/05/05 11:25:27] INFO: [TRAIN] epoch: 51, iter: 1275/1500, loss: 0.2858, lr: 0.000016, batch_cost: 0.5446, reader_cost: 0.00173, ips: 14.6889 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:02
# [2026/05/05 11:25:38] INFO: [TRAIN] epoch: 52, iter: 1280/1500, loss: 0.3437, lr: 0.000016, batch_cost: 2.2581, reader_cost: 1.30402, ips: 3.5428 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:08:16
# [2026/05/05 11:25:44] INFO: [TRAIN] epoch: 52, iter: 1285/1500, loss: 0.2598, lr: 0.000016, batch_cost: 1.0599, reader_cost: 0.00384, ips: 7.5477 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:47
# [2026/05/05 11:25:48] INFO: [TRAIN] epoch: 52, iter: 1290/1500, loss: 0.3364, lr: 0.000015, batch_cost: 0.8722, reader_cost: 0.00136, ips: 9.1718 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:03
# [2026/05/05 11:25:51] INFO: [TRAIN] epoch: 52, iter: 1295/1500, loss: 0.2299, lr: 0.000015, batch_cost: 0.5525, reader_cost: 0.00096, ips: 14.4800 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:53
# [2026/05/05 11:25:53] INFO: [TRAIN] epoch: 52, iter: 1300/1500, loss: 0.1874, lr: 0.000014, batch_cost: 0.5314, reader_cost: 0.00022, ips: 15.0559 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:46
# [2026/05/05 11:25:53] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 8s 139ms/step - batch_cost: 0.1381 - reader cost: 0.0929
# [2026/05/05 11:26:01] INFO: [EVAL] #Images: 56 mIoU: 0.8559 Acc: 0.9373 Kappa: 0.8771 Dice: 0.9219
# [2026/05/05 11:26:01] INFO: [EVAL] Class IoU:
# [0.8202 0.8346 0.913 ]
# [2026/05/05 11:26:01] INFO: [EVAL] Class Precision:
# [0.9304 0.8715 0.9713]
# [2026/05/05 11:26:01] INFO: [EVAL] Class Recall:
# [0.8738 0.9517 0.9383]
# [2026/05/05 11:26:03] INFO: [EVAL] The model with the best validation mIoU (0.8893) was saved at iter 1100.
# [2026/05/05 11:26:16] INFO: [TRAIN] epoch: 53, iter: 1305/1500, loss: 0.2498, lr: 0.000014, batch_cost: 2.6621, reader_cost: 1.47531, ips: 3.0051 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:08:39
# [2026/05/05 11:26:21] INFO: [TRAIN] epoch: 53, iter: 1310/1500, loss: 0.2692, lr: 0.000014, batch_cost: 1.0551, reader_cost: 0.20393, ips: 7.5822 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:20
# [2026/05/05 11:26:25] INFO: [TRAIN] epoch: 53, iter: 1315/1500, loss: 0.2643, lr: 0.000013, batch_cost: 0.8441, reader_cost: 0.00422, ips: 9.4777 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:36
# [2026/05/05 11:26:29] INFO: [TRAIN] epoch: 53, iter: 1320/1500, loss: 0.2921, lr: 0.000013, batch_cost: 0.6661, reader_cost: 0.00069, ips: 12.0105 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:59
# [2026/05/05 11:26:31] INFO: [TRAIN] epoch: 53, iter: 1325/1500, loss: 0.2317, lr: 0.000013, batch_cost: 0.5293, reader_cost: 0.00066, ips: 15.1130 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:32
# [2026/05/05 11:26:45] INFO: [TRAIN] epoch: 54, iter: 1330/1500, loss: 0.2603, lr: 0.000012, batch_cost: 2.6454, reader_cost: 1.45785, ips: 3.0241 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:07:29
# [2026/05/05 11:26:50] INFO: [TRAIN] epoch: 54, iter: 1335/1500, loss: 0.2275, lr: 0.000012, batch_cost: 0.9929, reader_cost: 0.00320, ips: 8.0570 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:43
# [2026/05/05 11:26:53] INFO: [TRAIN] epoch: 54, iter: 1340/1500, loss: 0.2181, lr: 0.000012, batch_cost: 0.7676, reader_cost: 0.00166, ips: 10.4224 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:02:02
# [2026/05/05 11:26:56] INFO: [TRAIN] epoch: 54, iter: 1345/1500, loss: 0.2327, lr: 0.000011, batch_cost: 0.5394, reader_cost: 0.00071, ips: 14.8318 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:23
# [2026/05/05 11:26:59] INFO: [TRAIN] epoch: 54, iter: 1350/1500, loss: 0.2011, lr: 0.000011, batch_cost: 0.5423, reader_cost: 0.00021, ips: 14.7517 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:21
# [2026/05/05 11:26:59] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 7s 124ms/step - batch_cost: 0.1238 - reader cost: 0.0851
# [2026/05/05 11:27:06] INFO: [EVAL] #Images: 56 mIoU: 0.8963 Acc: 0.9613 Kappa: 0.9229 Dice: 0.9448
# [2026/05/05 11:27:06] INFO: [EVAL] Class IoU:
# [0.8451 0.8944 0.9494]
# [2026/05/05 11:27:06] INFO: [EVAL] Class Precision:
# [0.9448 0.939  0.9732]
# [2026/05/05 11:27:06] INFO: [EVAL] Class Recall:
# [0.8889 0.9496 0.9749]
# [2026/05/05 11:27:07] INFO: [EVAL] The model with the best validation mIoU (0.8963) was saved at iter 1350.
# [2026/05/05 11:27:22] INFO: [TRAIN] epoch: 55, iter: 1355/1500, loss: 0.2237, lr: 0.000011, batch_cost: 2.8266, reader_cost: 1.90328, ips: 2.8302 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:06:49
# [2026/05/05 11:27:26] INFO: [TRAIN] epoch: 55, iter: 1360/1500, loss: 0.2686, lr: 0.000010, batch_cost: 0.8251, reader_cost: 0.00115, ips: 9.6959 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:55
# [2026/05/05 11:27:29] INFO: [TRAIN] epoch: 55, iter: 1365/1500, loss: 0.2467, lr: 0.000010, batch_cost: 0.5649, reader_cost: 0.00293, ips: 14.1619 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:16
# [2026/05/05 11:27:36] INFO: [TRAIN] epoch: 55, iter: 1370/1500, loss: 0.2977, lr: 0.000009, batch_cost: 1.5731, reader_cost: 1.01593, ips: 5.0856 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:24
# [2026/05/05 11:27:39] INFO: [TRAIN] epoch: 55, iter: 1375/1500, loss: 0.2097, lr: 0.000009, batch_cost: 0.5260, reader_cost: 0.00020, ips: 15.2083 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:05
# [2026/05/05 11:27:53] INFO: [TRAIN] epoch: 56, iter: 1380/1500, loss: 0.2383, lr: 0.000009, batch_cost: 2.8830, reader_cost: 1.95942, ips: 2.7749 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:05:45
# [2026/05/05 11:27:58] INFO: [TRAIN] epoch: 56, iter: 1385/1500, loss: 0.2702, lr: 0.000008, batch_cost: 0.8177, reader_cost: 0.00190, ips: 9.7838 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:34
# [2026/05/05 11:28:02] INFO: [TRAIN] epoch: 56, iter: 1390/1500, loss: 0.2133, lr: 0.000008, batch_cost: 0.8630, reader_cost: 0.00284, ips: 9.2698 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:34
# [2026/05/05 11:28:05] INFO: [TRAIN] epoch: 56, iter: 1395/1500, loss: 0.2544, lr: 0.000008, batch_cost: 0.5872, reader_cost: 0.00214, ips: 13.6245 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:01
# [2026/05/05 11:28:08] INFO: [TRAIN] epoch: 56, iter: 1400/1500, loss: 0.2175, lr: 0.000007, batch_cost: 0.5383, reader_cost: 0.00021, ips: 14.8626 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:53
# [2026/05/05 11:28:08] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 7s 122ms/step - batch_cost: 0.1212 - reader cost: 0.0821
# [2026/05/05 11:28:14] INFO: [EVAL] #Images: 56 mIoU: 0.9005 Acc: 0.9620 Kappa: 0.9240 Dice: 0.9472
# [2026/05/05 11:28:14] INFO: [EVAL] Class IoU:
# [0.8569 0.8951 0.9494]
# [2026/05/05 11:28:14] INFO: [EVAL] Class Precision:
# [0.9201 0.959  0.9681]
# [2026/05/05 11:28:14] INFO: [EVAL] Class Recall:
# [0.9258 0.9307 0.9801]
# [2026/05/05 11:28:16] INFO: [EVAL] The model with the best validation mIoU (0.9005) was saved at iter 1400.
# [2026/05/05 11:28:30] INFO: [TRAIN] epoch: 57, iter: 1405/1500, loss: 0.2065, lr: 0.000007, batch_cost: 2.6625, reader_cost: 1.75046, ips: 3.0047 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:04:12
# [2026/05/05 11:28:35] INFO: [TRAIN] epoch: 57, iter: 1410/1500, loss: 0.2021, lr: 0.000007, batch_cost: 1.0674, reader_cost: 0.13310, ips: 7.4945 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:36
# [2026/05/05 11:28:38] INFO: [TRAIN] epoch: 57, iter: 1415/1500, loss: 0.3051, lr: 0.000006, batch_cost: 0.6493, reader_cost: 0.00227, ips: 12.3202 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:55
# [2026/05/05 11:28:44] INFO: [TRAIN] epoch: 57, iter: 1420/1500, loss: 0.2106, lr: 0.000006, batch_cost: 1.1455, reader_cost: 0.54078, ips: 6.9838 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:31
# [2026/05/05 11:28:47] INFO: [TRAIN] epoch: 57, iter: 1425/1500, loss: 0.2659, lr: 0.000006, batch_cost: 0.5248, reader_cost: 0.00022, ips: 15.2448 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:39
# [2026/05/05 11:29:00] INFO: [TRAIN] epoch: 58, iter: 1430/1500, loss: 0.2029, lr: 0.000005, batch_cost: 2.6531, reader_cost: 1.78505, ips: 3.0154 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:03:05
# [2026/05/05 11:29:04] INFO: [TRAIN] epoch: 58, iter: 1435/1500, loss: 0.2083, lr: 0.000005, batch_cost: 0.9015, reader_cost: 0.00022, ips: 8.8746 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:58
# [2026/05/05 11:29:10] INFO: [TRAIN] epoch: 58, iter: 1440/1500, loss: 0.2780, lr: 0.000004, batch_cost: 1.1022, reader_cost: 0.00128, ips: 7.2580 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:06
# [2026/05/05 11:29:13] INFO: [TRAIN] epoch: 58, iter: 1445/1500, loss: 0.2986, lr: 0.000004, batch_cost: 0.5476, reader_cost: 0.00125, ips: 14.6079 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:30
# [2026/05/05 11:29:15] INFO: [TRAIN] epoch: 58, iter: 1450/1500, loss: 0.2302, lr: 0.000004, batch_cost: 0.5345, reader_cost: 0.00023, ips: 14.9677 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:26
# [2026/05/05 11:29:15] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 8s 135ms/step - batch_cost: 0.1350 - reader cost: 0.0905
# [2026/05/05 11:29:23] INFO: [EVAL] #Images: 56 mIoU: 0.8971 Acc: 0.9609 Kappa: 0.9224 Dice: 0.9453
# [2026/05/05 11:29:23] INFO: [EVAL] Class IoU:
# [0.8482 0.8952 0.9479]
# [2026/05/05 11:29:23] INFO: [EVAL] Class Precision:
# [0.9012 0.9504 0.9728]
# [2026/05/05 11:29:23] INFO: [EVAL] Class Recall:
# [0.9351 0.939  0.9737]
# [2026/05/05 11:29:24] INFO: [EVAL] The model with the best validation mIoU (0.9005) was saved at iter 1400.
# [2026/05/05 11:29:36] INFO: [TRAIN] epoch: 59, iter: 1455/1500, loss: 0.2323, lr: 0.000003, batch_cost: 2.3024, reader_cost: 1.33039, ips: 3.4746 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:01:43
# [2026/05/05 11:29:42] INFO: [TRAIN] epoch: 59, iter: 1460/1500, loss: 0.2478, lr: 0.000003, batch_cost: 1.2730, reader_cost: 0.25045, ips: 6.2841 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:50
# [2026/05/05 11:29:47] INFO: [TRAIN] epoch: 59, iter: 1465/1500, loss: 0.2969, lr: 0.000003, batch_cost: 0.8595, reader_cost: 0.00198, ips: 9.3079 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:30
# [2026/05/05 11:29:49] INFO: [TRAIN] epoch: 59, iter: 1470/1500, loss: 0.2647, lr: 0.000002, batch_cost: 0.5417, reader_cost: 0.00107, ips: 14.7673 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:16
# [2026/05/05 11:29:52] INFO: [TRAIN] epoch: 59, iter: 1475/1500, loss: 0.2462, lr: 0.000002, batch_cost: 0.5275, reader_cost: 0.00021, ips: 15.1646 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:13
# [2026/05/05 11:30:05] INFO: [TRAIN] epoch: 60, iter: 1480/1500, loss: 0.1635, lr: 0.000002, batch_cost: 2.5697, reader_cost: 1.66620, ips: 3.1132 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:51
# [2026/05/05 11:30:10] INFO: [TRAIN] epoch: 60, iter: 1485/1500, loss: 0.1937, lr: 0.000001, batch_cost: 0.9888, reader_cost: 0.00213, ips: 8.0910 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:14
# [2026/05/05 11:30:15] INFO: [TRAIN] epoch: 60, iter: 1490/1500, loss: 0.2513, lr: 0.000001, batch_cost: 0.9726, reader_cost: 0.00072, ips: 8.2255 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:09
# [2026/05/05 11:30:17] INFO: [TRAIN] epoch: 60, iter: 1495/1500, loss: 0.2386, lr: 0.000001, batch_cost: 0.5426, reader_cost: 0.00022, ips: 14.7439 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:02
# [2026/05/05 11:30:20] INFO: [TRAIN] epoch: 60, iter: 1500/1500, loss: 0.2821, lr: 0.000000, batch_cost: 0.5308, reader_cost: 0.00021, ips: 15.0725 samples/sec, max_mem_reserved: 5278 MB, max_mem_allocated: 4066 MB | ETA 00:00:00
# [2026/05/05 11:30:20] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 8s 148ms/step - batch_cost: 0.1470 - reader cost: 0.1008
# [2026/05/05 11:30:28] INFO: [EVAL] #Images: 56 mIoU: 0.8794 Acc: 0.9543 Kappa: 0.9096 Dice: 0.9351
# [2026/05/05 11:30:28] INFO: [EVAL] Class IoU:
# [0.8222 0.8744 0.9417]
# [2026/05/05 11:30:28] INFO: [EVAL] Class Precision:
# [0.961  0.904  0.9779]
# [2026/05/05 11:30:28] INFO: [EVAL] Class Recall:
# [0.8506 0.964  0.9621]
# [2026/05/05 11:30:30] INFO: [EVAL] The model with the best validation mIoU (0.9005) was saved at iter 1400.
# <class 'paddle.nn.layer.conv.Conv2D'>'s flops has been counted
# <class 'paddle.nn.layer.norm.BatchNorm2D'>'s flops has been counted
# <class 'paddle.nn.layer.activation.ReLU'>'s flops has been counted
# Cannot find suitable count function for <class 'paddle.nn.layer.activation.GELU'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.common.Dropout'>'s flops has been counted
# Cannot find suitable count function for <class 'paddleseg.models.backbones.transformer_utils.DropPath'>. Treat it as zero FLOPs.
# Cannot find suitable count function for <class 'paddle.nn.layer.pooling.AdaptiveMaxPool2D'>. Treat it as zero FLOPs.
# <class 'paddle.nn.layer.pooling.AvgPool2D'>'s flops has been counted
# <class 'paddle.nn.layer.pooling.AdaptiveAvgPool2D'>'s flops has been counted
# Total Flops: 33746015744     Total Params: 16869443

# %%
# 0.9005

# %%
# !python tools/val.py --help

# usage: val.py [-h] [--config CONFIG] [--model_path MODEL_PATH]
#               [--num_workers NUM_WORKERS] [--device {cpu,gpu,xpu,npu,mlu}]
#               [--aug_eval] [--scales SCALES [SCALES ...]] [--flip_horizontal]
#               [--flip_vertical] [--is_slide] [--crop_size CROP_SIZE CROP_SIZE]
#               [--stride STRIDE STRIDE] [--data_format DATA_FORMAT]
#               [--auc_roc AUC_ROC] [--opts OPTS [OPTS ...]] [--use_multilabel]

# %%
# !python tools/val.py \
       --config configs/rtformer/rtformer_uterus.yml \
       --model_path /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/best_model/model.pdparams \
       --device gpu \
       --num_workers 8
# Out:
# [2026/05/05 11:30:56] WARNING: Add the `num_classes` in train_dataset and val_dataset config to model config. We suggest you manually set `num_classes` in model config.
# [2026/05/05 11:30:56] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/05 11:30:56] INFO:
# ---------------Config Information---------------
# batch_size: 8
# iters: 500
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# lr_scheduler:
#   end_lr: 1.0e-07
#   learning_rate: 0.0001
#   power: 1.0
#   type: PolynomialDecay
#   warmup_iters: 100
#   warmup_start_lr: 1.0e-06
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# ------------------------------------------------
#
# [2026/05/05 11:30:56] INFO: Set device: gpu
# [2026/05/05 11:30:56] INFO: Use the following config to build model
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# W0505 11:30:56.782603 50867 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0505 11:30:56.782651 50867 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/05 11:30:57] INFO: Loading pretrained model from https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
# [2026/05/05 11:30:57] WARNING: [SKIP] Shape of pretrained params seghead.conv2.weight doesn't match.(Pretrained: [150, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/05 11:30:57] WARNING: [SKIP] Shape of pretrained params seghead.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 11:30:57] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.weight doesn't match.(Pretrained: [150, 128, 1, 1], Actual: [3, 128, 1, 1])
# [2026/05/05 11:30:57] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 11:30:57] INFO: There are 257/261 variables loaded into RTFormer.
# [2026/05/05 11:30:57] INFO: Loading pretrained model from /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/best_model/model.pdparams
# [2026/05/05 11:30:57] INFO: There are 261/261 variables loaded into RTFormer.
# [2026/05/05 11:30:57] INFO: Loaded trained weights successfully.
# [2026/05/05 11:30:57] INFO: Use the following config to build val_dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# [2026/05/05 11:30:57] INFO: Start evaluating (total_samples: 56, total_iters: 56)...
# 56/56 [==============================] - 8s 142ms/step - batch_cost: 0.1408 - reader cost: 0.0322
# [2026/05/05 11:31:05] INFO: [EVAL] #Images: 56 mIoU: 0.9005 Acc: 0.9620 Kappa: 0.9240 Dice: 0.9472
# [2026/05/05 11:31:05] INFO: [EVAL] Class IoU:
# [0.8569 0.8951 0.9494]
# [2026/05/05 11:31:05] INFO: [EVAL] Class Precision:
# [0.9201 0.959  0.9681]
# [2026/05/05 11:31:05] INFO: [EVAL] Class Recall:
# [0.9258 0.9307 0.9801]

# %%
# !python tools/predict.py \
       --config configs/rtformer/rtformer_uterus.yml \
       --model_path /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/best_model/model.pdparams \
       --device gpu \
       --image_path /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/images \
       --save_dir /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/infer_images/
# Out:
# [2026/05/05 11:31:17] WARNING: Add the `num_classes` in train_dataset and val_dataset config to model config. We suggest you manually set `num_classes` in model config.
# [2026/05/05 11:31:17] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/05 11:31:17] INFO:
# ---------------Config Information---------------
# batch_size: 8
# iters: 500
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# lr_scheduler:
#   end_lr: 1.0e-07
#   learning_rate: 0.0001
#   power: 1.0
#   type: PolynomialDecay
#   warmup_iters: 100
#   warmup_start_lr: 1.0e-06
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# ------------------------------------------------
#
# [2026/05/05 11:31:17] INFO: Set device: gpu:0
# [2026/05/05 11:31:17] INFO: Use the following config to build model
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# W0505 11:31:17.155989 51034 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0505 11:31:17.156041 51034 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/05 11:31:17] INFO: Loading pretrained model from https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
# [2026/05/05 11:31:17] WARNING: [SKIP] Shape of pretrained params seghead.conv2.weight doesn't match.(Pretrained: [150, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/05 11:31:17] WARNING: [SKIP] Shape of pretrained params seghead.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 11:31:17] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.weight doesn't match.(Pretrained: [150, 128, 1, 1], Actual: [3, 128, 1, 1])
# [2026/05/05 11:31:17] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 11:31:17] INFO: There are 257/261 variables loaded into RTFormer.
# [2026/05/05 11:31:17] INFO: The number of images: 56
# [2026/05/05 11:31:17] INFO: Loading pretrained model from /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/best_model/model.pdparams
# [2026/05/05 11:31:17] INFO: There are 261/261 variables loaded into RTFormer.
# [2026/05/05 11:31:17] INFO: Start to predict...
# 56/56 [==============================] - 14s 249ms/step
# [2026/05/05 11:31:31] INFO: Predicted images are saved in /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/infer_images/added_prediction and /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/infer_images/pseudo_color_prediction .

# %%
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import cv2
# ---------------- CONFIG ----------------
val_dir = "/content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/infer_images/pseudo_color_prediction"

# visualization layout
N = 8
cols = 4
rows = int(np.ceil(N / cols))

# random image selection
all_imgs = [os.path.join(val_dir, f)
            for f in os.listdir(val_dir)
            if f.lower().endswith((".jpg", ".png", ".jpeg"))]

sample_imgs = random.sample(all_imgs, N)

plt.figure(figsize=(4 * cols, 2 * rows))

for ii, image in enumerate(sample_imgs):
    plt.subplot(2, 4, ii+1)

    img = cv2.imread(image)

    plt.subplot(rows, cols, ii + 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# !python tools/export.py --help

# %%
# !python tools/export.py \
       --config configs/rtformer/rtformer_uterus.yml \
       --model_path /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/best_model/model.pdparams \
       --save_dir output_inference/rtformer_uterus \
       --input_shape 1 3 512 1024
# Out:
# [2026/05/05 11:46:00] WARNING: Add the `num_classes` in train_dataset and val_dataset config to model config. We suggest you manually set `num_classes` in model config.
# [2026/05/05 11:46:00] INFO: Use the following config to build model
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# W0505 11:46:00.356968 55018 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 13.0, Runtime API Version: 11.8
# W0505 11:46:00.357923 55018 gpu_resources.cc:164] device: 0, cuDNN Version: 9.8.
# [2026/05/05 11:46:00] INFO: Loading pretrained model from https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
# [2026/05/05 11:46:00] WARNING: [SKIP] Shape of pretrained params seghead.conv2.weight doesn't match.(Pretrained: [150, 256, 1, 1], Actual: [3, 256, 1, 1])
# [2026/05/05 11:46:00] WARNING: [SKIP] Shape of pretrained params seghead.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 11:46:00] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.weight doesn't match.(Pretrained: [150, 128, 1, 1], Actual: [3, 128, 1, 1])
# [2026/05/05 11:46:00] WARNING: [SKIP] Shape of pretrained params seghead_extra.conv2.bias doesn't match.(Pretrained: [150], Actual: [3])
# [2026/05/05 11:46:00] INFO: There are 257/261 variables loaded into RTFormer.
# [2026/05/05 11:46:01] INFO: Loaded trained params successfully.
# [2026/05/05 11:46:01] INFO:
# ------------Environment Information-------------
# platform: Linux-6.6.113+-x86_64-with-glibc2.35
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Paddle compiled with cuda: True
# NVCC: Build cuda_12.8.r12.8/compiler.35583870_0
# cudnn: 90.8
# GPUs used: 1
# CUDA_VISIBLE_DEVICES: None
# GPU: ['GPU 0: Tesla T4']
# GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
# PaddleSeg: 0.0.0.dev0
# PaddlePaddle: 2.6.2
# OpenCV: 4.13.0
# ------------------------------------------------
# [2026/05/05 11:46:01] INFO:
# ---------------Config Information---------------
# batch_size: 8
# iters: 500
# train_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train
#   mode: train
#   num_classes: 3
#   train_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/train/train.txt
#   transforms:
#   - max_scale_factor: 2.0
#     min_scale_factor: 0.5
#     scale_step_size: 0.25
#     type: ResizeStepScaling
#   - crop_size:
#     - 1024
#     - 512
#     type: RandomPaddingCrop
#   - type: RandomHorizontalFlip
#   - brightness_range: 0.4
#     contrast_range: 0.4
#     saturation_range: 0.4
#     type: RandomDistort
#   - type: Normalize
#   type: Dataset
# val_dataset:
#   dataset_root: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid
#   mode: val
#   num_classes: 3
#   transforms:
#   - type: Normalize
#   type: Dataset
#   val_path: /content/gdrive/MyDrive/Pytorch-Models/datasets/sispanseg/valid/val.txt
# optimizer:
#   beta1: 0.9
#   beta2: 0.999
#   type: AdamW
#   weight_decay: 0.05
# lr_scheduler:
#   end_lr: 1.0e-07
#   learning_rate: 0.0001
#   power: 1.0
#   type: PolynomialDecay
#   warmup_iters: 100
#   warmup_start_lr: 1.0e-06
# loss:
#   coef:
#   - 1
#   - 0.4
#   types:
#   - type: CrossEntropyLoss
#   - type: CrossEntropyLoss
# model:
#   base_channels: 64
#   drop_path_rate: 0.1
#   head_channels: 128
#   num_classes: 3
#   pretrained: https://paddleseg.bj.bcebos.com/dygraph/ade20k/rtformer_base_ade20k_512x512_160k/model.pdparams
#   type: RTFormer
#   use_injection:
#   - true
#   - false
# ------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/paddle/jit/api.py:310: UserWarning: full_graph=False is not supported in Python 3.12+. Set full_graph=True automatically
#   warnings.warn(
# I0505 11:46:02.843307 55018 program_interpreter.cc:212] New Executor is Running.
# [2026/05/05 11:46:03] INFO:
# ---------------Deploy Information---------------
# Deploy:
#   input_shape:
#   - 1
#   - 3
#   - 512
#   - 1024
#   model: model.pdmodel
#   output_dtype: int32
#   output_op: argmax
#   params: model.pdiparams
#   transforms:
#   - type: Normalize
#
# [2026/05/05 11:46:03] INFO: The inference model is saved in output_inference/rtformer_uterus

# %%
def normalize(img, mean, std):
    img = img / 255.0
    mean = np.array(mean)[np.newaxis, np.newaxis, :]
    std = np.array(std)[np.newaxis, np.newaxis, :]
    img -= mean
    img /= std
    return img

def preprocess(img, img_size):
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    img = cv2.resize(img, (img_size[0], img_size[1]))
    img = img[:, :, ::-1].astype('float32')  # bgr -> rgb
    img = normalize(img, mean, std)
    img = img.transpose((2, 0, 1))  # hwc -> chw
    return img[np.newaxis, :]

# %%
import paddle
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
import paddle.inference as paddle_infer
import cv2
import numpy as np

config = paddle_infer.Config("output_inference/rtformer_uterus/model.pdmodel", "output_inference/rtformer_uterus/model.pdiparams")
config.enable_use_gpu(100, 0)
predictor = paddle_infer.create_predictor(config)

img = cv2.imread("/content/gdrive/MyDrive/PaddleDet-Models/datasets/sispanseg/valid/images/Laparoscopic-Myomectomy-with-Baseball-Suturing-22-_jpg.rf.04929e16d4ace3507c937c4e1ce8a333.jpg")
im_size = [1024, 512]
data = preprocess(img, im_size)

input_names = predictor.get_input_names()
input_tensor = predictor.get_input_handle(input_names[0])
input_tensor.reshape(img.shape)
input_tensor.copy_from_cpu(data.copy())

predictor.run()
output_names = predictor.get_output_names()
output_tensor = predictor.get_output_handle(output_names[0])
output_data = output_tensor.copy_to_cpu()
print(output_data.shape)
# Out:
# (1, 512, 1024)

# %%
CATEGORY_COLORS = {
    0: [0, 0, 0],           # Things (Black)
    1: [255, 0, 255],       # Uterus (Magenta)
    2: [0, 75, 150],        # BG (Brown)
}
orig_h, orig_w = img.shape[:2]

# 1. Create a color palette array (fast lookup)
palette_map = np.zeros((256, 3), dtype=np.uint8)
for i, color in CATEGORY_COLORS.items():
    palette_map[i] = color

# 2. Apply the colors in one vectorized step
mask = output_data[0].squeeze().astype(np.uint8)
color_mask = palette_map[mask] # Instant mapping

color_mask = cv2.resize(color_mask, (orig_w, orig_h))

# 3. Create a fast overlay
overlay = cv2.addWeighted(img, 0.3, color_mask, 0.7, 0)

import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import numpy as np
import os
import random
# ---------------- CONFIG ----------------
val_dir = "/content/gdrive/MyDrive/PaddleDet-Models/datasets/sispanseg/valid/images/"

# visualization layout
N = 8
cols = 4
rows = int(np.ceil(N / cols))

# random image selection
all_imgs = [os.path.join(val_dir, f)
            for f in os.listdir(val_dir)
            if f.lower().endswith((".jpg", ".png", ".jpeg"))]

sample_imgs = random.sample(all_imgs, N)

plt.figure(figsize=(4 * cols, 3 * rows))

for ii, image in enumerate(sample_imgs):
    plt.subplot(2, 4, ii+1)

    img = cv2.imread(image)
    data = preprocess(img, im_size)

    input_names = predictor.get_input_names()
    input_tensor = predictor.get_input_handle(input_names[0])
    input_tensor.reshape(img.shape)
    input_tensor.copy_from_cpu(data.copy())

    predictor.run()
    output_names = predictor.get_output_names()
    output_tensor = predictor.get_output_handle(output_names[0])
    output_data = output_tensor.copy_to_cpu()

    orig_h, orig_w = img.shape[:2]

    mask = output_data[0].squeeze().astype(np.uint8)
    color_mask = palette_map[mask] # Instant mapping

    color_mask = cv2.resize(color_mask, (orig_w, orig_h))
    overlay = cv2.addWeighted(img, 0.3, color_mask, 0.7, 0)

    plt.subplot(rows, cols, ii + 1)
    plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# !pip install onnx onnxscript paddle2onnx==1.1.0
# Out:
# Collecting onnx
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxscript
#   Downloading onnxscript-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting paddle2onnx==1.1.0
#   Downloading paddle2onnx-1.1.0-cp312-cp312-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (477 bytes)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Collecting onnx_ir<2,>=0.1.16 (from onnxscript)
#   Downloading onnx_ir-0.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (26.1)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.12/dist-packages (from onnx_ir<2,>=0.1.16->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.16->onnxscript) (1.3.0)
# Downloading paddle2onnx-1.1.0-cp312-cp312-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 16.0 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 97.3 MB/s eta 0:00:00
# Downloading onnxscript-0.7.0-py3-none-any.whl (714 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 714.8/714.8 kB 53.8 MB/s eta 0:00:00
# Downloading onnx_ir-0.2.1-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.8/166.8 kB 17.5 MB/s eta 0:00:00
# Installing collected packages: paddle2onnx, onnx, onnx_ir, onnxscript
# Successfully installed onnx-1.21.0 onnx_ir-0.2.1 onnxscript-0.7.0 paddle2onnx-1.1.0

# %%
# !pip install onnxruntime-gpu
# Out:
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.25.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (26.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.6)
# Downloading onnxruntime_gpu-1.25.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (271.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.3/271.3 MB 5.9 MB/s eta 0:00:00
# Installing collected packages: onnxruntime-gpu
# Successfully installed onnxruntime-gpu-1.25.1

# %%
# !paddle2onnx --help

# %%
# !paddle2onnx --model_dir=./output_inference/rtformer_uterus/ \
            --model_filename model.pdmodel  \
            --params_filename model.pdiparams \
            --opset_version 11 \
            --save_file /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/rtformer_uterus.onnx
# Out:
# [Paddle2ONNX] Start to parse PaddlePaddle model...
# [Paddle2ONNX] Model file path: ./output_inference/rtformer_uterus/model.pdmodel
# [Paddle2ONNX] Paramters file path: ./output_inference/rtformer_uterus/model.pdiparams
# [Paddle2ONNX] Start to parsing Paddle model...
# [Paddle2ONNX] Use opset_version = 11 for ONNX export.
# [Paddle2ONNX] PaddlePaddle model is exported as ONNX format now.
# 2026-05-05 11:50:10 [INFO]	===============Make PaddlePaddle Better!================
# 2026-05-05 11:50:10 [INFO]	A little survey: https://iwenjuan.baidu.com/?code=r8hu2s

# %%
# %ls /content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/
# Out:
# best_model/    iter_1450/  rtformer_uterus.onnx       vdlrecords.1777978599.log
# infer_images/  iter_1500/  vdlrecords.1777977672.log  vdlrecords.1777979959.log

# %%
import onnxruntime
import numpy as np
import cv2
import torch

# Load image and preprocess
img_path = "/content/gdrive/MyDrive/PaddleDet-Models/datasets/sispanseg/valid/images/Laparoscopic-Myomectomy-with-Baseball-Suturing-22-_jpg.rf.04929e16d4ace3507c937c4e1ce8a333.jpg"

mean = np.array([0.485, 0.456, 0.406], dtype=np.float32)
std = np.array([0.229, 0.224, 0.225], dtype=np.float32)

img = cv2.imread(img_path)
img_resized = cv2.resize(img, (1024, 512))
img_input = img_resized[:, :, ::-1].astype(np.float32) / 255.0
img_input = (img_input - mean) / std
img_input = img_input.transpose(2, 0, 1)[np.newaxis, :]  # (1, 3, H, W)

# Run inference
session = onnxruntime.InferenceSession("/content/gdrive/MyDrive/PaddleDet-Models/PaddleSeg/paddleseg-outputs/rtformer_uterus/rtformer_uterus.onnx", providers=["CUDAExecutionProvider"])
input_name = session.get_inputs()[0].name
outputs = session.run(None, {input_name: img_input})

# Inspect inputs to confirm names and shapes (for debugging)
input_names = [inp.name for inp in session.get_inputs()]
print("Expected input names from ONNX model:", input_names)
print("Output:", [o.shape for o in outputs])
# Out:
# Expected input names from ONNX model: ['x']
# Output: [(1, 512, 1024)]

# %%
print(outputs[0])
# Out:
# [[[2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   ...
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]
#   [2 2 2 ... 2 2 2]]]

# %%
CATEGORY_COLORS = {
    0: [0, 0, 0],           # Things (Black)
    1: [255, 0, 255],       # Uterus (Magenta)
    2: [0, 75, 150],        # BG (Brown)
}
orig_h, orig_w = img.shape[:2]

# 1. Create a color palette array (fast lookup)
palette_map = np.zeros((256, 3), dtype=np.uint8)
for i, color in CATEGORY_COLORS.items():
    palette_map[i] = color

# 2. Apply the colors in one vectorized step
mask = outputs[0].squeeze().astype(np.uint8) # outputs[0] is already the class map, argmax is not needed
color_mask = palette_map[mask] # Instant mapping

color_mask = cv2.resize(color_mask, (orig_w, orig_h))

# 3. Create a fast overlay
overlay = cv2.addWeighted(img, 0.3, color_mask, 0.7, 0)

import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import numpy as np
import os
import random
# ---------------- CONFIG ----------------
val_dir = "/content/gdrive/MyDrive/PaddleDet-Models/datasets/sispanseg/valid/images/"

# visualization layout
N = 8
cols = 4
rows = int(np.ceil(N / cols))

# random image selection
all_imgs = [os.path.join(val_dir, f)
            for f in os.listdir(val_dir)
            if f.lower().endswith((".jpg", ".png", ".jpeg"))]

sample_imgs = random.sample(all_imgs, N)

plt.figure(figsize=(4 * cols, 3 * rows))

for ii, image in enumerate(sample_imgs):
    plt.subplot(2, 4, ii+1)

    img = cv2.imread(image)
    img_resized = cv2.resize(img, (1024, 512))
    img_input = img_resized[:, :, ::-1].astype(np.float32) / 255.0
    img_input = (img_input - mean) / std
    img_input = img_input.transpose(2, 0, 1)[np.newaxis, :]  # (1, 3, H, W)

    outputs = session.run(None, {input_name: img_input})

    orig_h, orig_w = img.shape[:2]

    mask = outputs[0].squeeze().astype(np.uint8)
    color_mask = palette_map[mask] # Instant mapping

    color_mask = cv2.resize(color_mask, (orig_w, orig_h))
    overlay = cv2.addWeighted(img, 0.3, color_mask, 0.7, 0)

    plt.subplot(rows, cols, ii + 1)
    plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
    plt.axis("off")

plt.tight_layout()
plt.show()
